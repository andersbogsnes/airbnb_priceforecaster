# %%
from airbnb_priceforecaster.data import AirBnBDataset

# %%
dataset = AirBnBDataset(year=2020, month=5, day=30)

# %%
dataset.file_path
# Out:
# PosixPath('/home/anders/projects/airbnb_priceforecaster/processed/listings.parquet')

# %%
dataset.x.host_identity_verified
# Out:
# 0        <NA>
# 1        <NA>
# 2        <NA>
# 3        <NA>
# 4        <NA>
#          ...
# 28191    <NA>
# 28192    <NA>
# 28193    <NA>
# 28194    <NA>
# 28195    <NA>
# Name: host_identity_verified, Length: 28196, dtype: Int8

# %%
dataset.plot.missing_data()
