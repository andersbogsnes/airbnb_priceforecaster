# %%
# %load_ext autoreload
# %autoreload 2

# %%
from airbnb_priceforecaster.data import AirBnBDataset
from airbnb_priceforecaster.features import features
from ml_tooling import Model
from sklearn.ensemble import RandomForestRegressor

# %%
dataset = AirBnBDataset(year=2020, month=5, day=30)

# %%
dataset.x
# Out:
#                                              house_rules host_since  \
# 0                           No smoking allowed! No pets. 2009-05-12
# 1      We will leave the house clean and in good and ... 2010-04-17
# 2      Please be respectful to the neighbors and keep... 2010-04-22
# 3      Smoking is allowed on the balcony only.  Pleas... 2010-05-15
# 4                  Please respect that this is our home. 2010-05-18
# ...                                                  ...        ...
# 28191                                Ingen sko indendørs 2014-04-17
# 28192                                    No shoes inside 2019-09-22
# 28193                                               <NA> 2013-08-19
# 28194                                               <NA> 2016-07-05
# 28195                                               <NA> 2012-08-25
#
#                                         host_location host_response_time  \
# 0      Copenhagen, Capital Region of Denmark, Denmark                NaN
# 1      Copenhagen, Capital Region of Denmark, Denmark                NaN
# 2      Copenhagen, Capital Region of Denmark, Denmark     within an hour
# 3      Copenhagen, Capital Region of Denmark, Denmark       within a day
# 4      Copenhagen, Capital Region of Denmark, Denmark                NaN
# ...                                               ...                ...
# 28191  Copenhagen, Capital Region of Denmark, Denmark       within a day
# 28192                                              DK                NaN
# 28193  Copenhagen, Capital Region of Denmark, Denmark                NaN
# 28194                             Copenhagen, Denmark                NaN
# 28195                             Copenhagen, Denmark     within an hour
#
#        host_acceptance_rate host_neighbourhood  host_listings_count  \
# 0                        33           Nørrebro                    1
# 1                        19           Indre By                    1
# 2                       100           Indre By                    4
# 3                        17          Vesterbro                    1
# 4                      <NA>           Østerbro                    1
# ...                     ...                ...                  ...
# 28191                  <NA>                NaN                    0
# 28192                  <NA>                NaN                    0
# 28193                  <NA>                NaN                    1
# 28194                  <NA>                NaN                    1
# 28195                    99           Indre By                   13
#
#        host_total_listings_count  host_has_profile_pic  \
# 0                              1                  True
# 1                              1                  True
# 2                              4                  True
# 3                              1                  True
# 4                              1                  True
# ...                          ...                   ...
# 28191                          0                  True
# 28192                          0                  True
# 28193                          1                  True
# 28194                          1                  True
# 28195                         13                  True
#
#        host_identity_verified  ... printer  ceiling_fan  memory_foam_mattress  \
# 0                       False  ...   False        False                 False
# 1                       False  ...   False        False                 False
# 2                        True  ...   False        False                 False
# 3                       False  ...   False        False                 False
# 4                        True  ...   False        False                 False
# ...                       ...  ...     ...          ...                   ...
# 28191                   False  ...   False        False                 False
# 28192                   False  ...   False        False                 False
# 28193                   False  ...   False        False                 False
# 28194                   False  ...   False        False                 False
# 28195                   False  ...   False        False                 False
#
#        amazon_echo projector_and_screen en_suite_bathroom  \
# 0            False                False             False
# 1            False                False             False
# 2            False                False             False
# 3            False                False             False
# 4            False                False             False
# ...            ...                  ...               ...
# 28191        False                False             False
# 28192        False                False             False
# 28193        False                False             False
# 28194        False                False             False
# 28195        False                False             False
#
#        central_air_conditioning  mini_fridge  beach_view  double_oven
# 0                         False        False       False        False
# 1                         False        False       False        False
# 2                         False        False       False        False
# 3                         False        False       False        False
# 4                         False        False       False        False
# ...                         ...          ...         ...          ...
# 28191                     False        False       False        False
# 28192                     False        False       False        False
# 28193                     False        False       False        False
# 28194                     False        False       False        False
# 28195                     False        False       False        False
#
# [28196 rows x 209 columns]

# %%
dataset.plot.target_correlation(top_n=10, bottom_n=10)
# Out:
# Output data already exists - skipping...
# Data is already preprocessed - skipping...
# <AxesSubplot:title={'center':'Feature-Target Correlation - Top 10 - Bottom 10'}, xlabel='Spearman Correlation', ylabel='Feature Labels'>

# %%
dataset.create_train_test()
# Out:
# Output data already exists - skipping...
# Data is already preprocessed - skipping...
# <AirBnBDataset - FileDataset>

# %%
clf = get_pipeline(RandomForestRegressor())

# %%
model = Model(clf)

# %%
result = model.score_estimator(dataset)
# Out:
# [16:42:17] - Scoring estimator...

# %%
result
# Out:
# <Result RandomForestRegressor: {'r2': -0.09}>
